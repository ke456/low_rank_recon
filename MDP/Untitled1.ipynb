# %%
from runtest import *

# %%
distQ, distR, er = runtest("liver.csv",max_eps=3000,max_cost=0.6)
# Out:
# r1: [1, 6, 4, 2, 5, 3, 0] 1.7357151682746936 eps: 0.942 0.910 0.244 eps: 0.857reward: 0.200 eps: 0.781 0.279 eps: 0.774 eps: 0.706 0.260 eps: 0.6910.282 eps: 0.6540.643 eps: 0.598eps: 0.556 eps: 0.295
# r2: [1, 4, 5, 6, 2, 3, 0] 1.3974406727124542
# re: [1, 4, 6, 2, 5, 3, 0]
#
# r1: [6, 1, 4, 2, 5, 0, 3] 1.1330154369808076
# r2: [6, 1, 5, 4, 2, 0, 3] 2.9995695169866834
# re: [6, 1, 4, 2, 5, 0, 3]
#
# r1: [4, 1, 6, 2, 5, 3, 0] 0.8762485558060391
# r2: [1, 3, 4, 6, 0, 2, 5] 3.878239989034748
# re: [1, 4, 6, 2, 5, 3, 0]
#
# r1: [3, 0, 1, 4, 6, 2, 5] 3.0329065916679054
# r2: [1, 3, 0, 4, 6, 5, 2] 3.5691770544802868
# re: [3, 0, 1, 4, 6, 2, 5]
#
# r1: [3, 0, 4, 1, 6, 2, 5] 4.546873796785532
# r2: [3, 0, 4, 1, 6, 2, 5] 4.546873796785533
# re: [3, 0, 4, 1, 6, 2, 5]
#
# r1: [1, 4, 6, 2, 5, 3, 0] 1.8326856657898305
# r2: [1, 3, 4, 0, 6, 2, 5] 1.2363073918790342
# re: [1, 4, 6, 2, 5, 3, 0]
#
# r1: [1, 6, 4, 2, 5, 3, 0] 1.6015978841034155
# r2: [4, 1, 6, 2, 5, 3, 0] 0.9207526582552892
# ...

# %%
print("Q:",distQ)
print("R:",distR)
# Out:
# Q: 260.97809742695733
# R: 309.6539794723144

# %%
plot_reward_per_episode(er)

# %%
from runtest import *

# %%
env = Data(unknown_rate=1)
env.loadfile("liver.csv")
env.normalize()
env.alpha = 0
env.cluster_K_means(7)

costs = None
if costs is None:
    env.set_costs()
else:
    env.set_costs(costs)
test_env = env.split(0.80)

res = []
for i in range(10):
    env.max_cost = (i+1)/10
    test_env.max_cost = env.max_cost
    res.append( runtest(env,test_env,max_eps=1000, epsilon_decay=0.999) )
    print()
    print("Q:",res[-1][0])
    print("R:",res[-1][1])
    print("N:",res[-1][2])
    print("M:",res[-1][3])
# Out:
# Q: 403.38941665924744
# R: 413.5942381228097
#
# Q: 322.61188869501206
# R: 386.93237581849803
#
# Q: 322.9503399121426
# R: 384.0672254657072
#
# Q: 273.2176490661482
# R: 350.2073371230075
#
# Q: 298.52411044540247
# R: 360.99181850288227
#
# Q: 283.913622786948
# R: 329.3321719533549
#
# Q: 292.8233301357491
# R: 323.1050213583497
#
# Q: 278.97961078267224
# R: 301.3606345715243
#
# Q: 273.6057123028588
# R: 282.981152422448
#
# Q: 264.62491517213533
# R: 264.62491517213533

# %%
Qs = [res[i][0] for i in range(len(res))]
Rs = [res[i][1] for i in range(len(res))]
Ns = [res[i][2] for i in range(len(res))]
Ms = [res[i][3] for i in range(len(res))]
print("Qs:",Qs)
print("Rs:",Rs)

import matplotlib.pyplot as plt
x = [(i+1)/n for i in range(n)]
plt.plot(x, Qs, x, Rs, x, Ns, x, Ms)
plt.show()
# Out:
# Qs: [403.38941665924744, 322.61188869501206, 322.9503399121426, 273.2176490661482, 298.52411044540247, 283.913622786948, 292.8233301357491, 278.97961078267224, 273.6057123028588, 264.62491517213533]
# Rs: [413.5942381228097, 386.93237581849803, 384.0672254657072, 350.2073371230075, 360.99181850288227, 329.3321719533549, 323.1050213583497, 301.3606345715243, 282.981152422448, 264.62491517213533]
